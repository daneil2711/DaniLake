# %%
import pandas as pd
import numpy as np
import sys
import os
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from feature_engine import encoding

# Adiciona o caminho da pasta 'py_functions' ao sys.path
sys.path.append(os.path.abspath('../../py_functions'))
from functions import iv_woe

# %% [markdown]
# ### Leitura das Bases de Dados

# %%
dados_turnover_jan = pd.read_csv("../Dados/Turnover_Funcionarios_Jan_23.txt",sep = "\t")

# %% [markdown]
# ### Análise Exploratória

# %%
dados_turnover_jan.describe()
# Out:
#        ID_respondente  ult_avaliacao_clima  qtde_projetos_3m  \
# count     3869.000000          3652.000000       3869.000000
# mean      1935.000000             0.621766          1.882140
# std       1117.028424             0.299004          1.495793
# min          1.000000             0.000000          0.000000
# 25%        968.000000             0.390000          1.000000
# 50%       1935.000000             0.690000          2.000000
# 75%       2902.000000             0.880000          3.000000
# max       3869.000000             1.000000          7.000000
#
#        qtde_projetos_6m  qtde_projetos_12m  qtde_projetos_24m  \
# count       3869.000000        3869.000000        3869.000000
# mean           3.792453           5.310416           7.828638
# std            1.195080           1.626292           2.346166
# min            2.000000           2.000000           2.000000
# 25%            3.000000           4.000000           6.000000
# 50%            4.000000           5.000000           8.000000
# 75%            5.000000           6.000000          10.000000
# max            7.000000          10.000000          15.000000
#
#        media_horas_trabalho_3m  media_horas_trabalho_6m  \
# count              3869.000000              3869.000000
# mean                166.064099               166.182735
# std                  13.741916                12.795058
# min                 139.000000               149.000000
# 25%                 155.000000               156.000000
# 50%                 162.000000               160.000000
# 75%                 177.000000               177.000000
# max                 214.000000               204.000000
#
#        media_horas_trabalho_12m  tempo_empresa  flag_promocao_3m  \
# count               3869.000000    3869.000000       3869.000000
# mean                 166.240889       3.529853          0.034634
# std                   14.097675       1.737699          0.182875
# min                  139.000000       1.000000          0.000000
# 25%                  155.000000       3.000000          0.000000
# 50%                  164.000000       3.000000          0.000000
# 75%                  176.000000       4.000000          0.000000
# max                  215.000000      11.000000          1.000000
#
#        flag_promocao_6m  flag_promocao_12m  flag_promocao_vida     turnover
# count       3869.000000        3869.000000         3869.000000  3869.000000
# mean           0.031016           0.029982            0.459809     0.175239
# std            0.173383           0.170559            0.498446     0.380221
# min            0.000000           0.000000            0.000000     0.000000
# 25%            0.000000           0.000000            0.000000     0.000000
# 50%            0.000000           0.000000            0.000000     0.000000
# 75%            0.000000           0.000000            1.000000     0.000000
# max            1.000000           1.000000            1.000000     1.000000

# %%
qtd = dados_turnover_jan['departamento'].value_counts(dropna=False)
freq = qtd/len(dados_turnover_jan)

tab = pd.DataFrame({
    'Quantidade': qtd,
    'Proporção': freq
})

tab
# Out:
#                    Quantidade  Proporção
# departamento
# vendas                   1015   0.262342
# dados                     886   0.229000
# TI/suporte                863   0.223055
# marketing/produto         697   0.180150
# RH/financeiro             408   0.105454

# %%
qtd = dados_turnover_jan['patamar_salario'].value_counts(dropna=False)
freq = qtd/len(dados_turnover_jan)

tab = pd.DataFrame({
    'Quantidade': qtd,
    'Proporção': freq
})

tab
# Out:
#                       Quantidade  Proporção
# patamar_salario
# 01_menor_igual_media        3220   0.832256
# 02_acima_media               649   0.167744

# %% [markdown]
# ### Análise do poder preditivo das variáveis (IV)

# %%
iv, woe = iv_woe(data = dados_turnover_jan, target = 'turnover')
# Out:
# Information value of ID_respondente is 0.032663
# Information value of ult_avaliacao_clima is 0.094439
# Information value of qtde_projetos_3m is 0.009395
# Information value of qtde_projetos_6m is 0.03194
# Information value of qtde_projetos_12m is 0.012572
# Information value of qtde_projetos_24m is 0.014719
# Information value of media_horas_trabalho_3m is 0.004882
# Information value of media_horas_trabalho_6m is 0.013801
# Information value of media_horas_trabalho_12m is 0.019898
# Information value of tempo_empresa is 0.088353
# Information value of flag_promocao_3m is 0.023954
# Information value of flag_promocao_6m is 0.000115
# Information value of flag_promocao_12m is 4.9e-05
# Information value of flag_promocao_vida is 0.008593
# Information value of departamento is 0.271602
# Information value of patamar_salario is 0.168649
# /usr/notebooks/MBA/py_functions/functions.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
# /usr/notebooks/MBA/py_functions/functions.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
# /usr/notebooks/MBA/py_functions/functions.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
# /usr/notebooks/MBA/py_functions/functions.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
# /usr/notebooks/MBA/py_functions/functions.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
# /usr/notebooks/MBA/py_functions/functions.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
# /usr/notebooks/MBA/py_functions/functions.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})

# %%
iv.sort_values(['IV'],ascending=False)
# Out:
#                    Variable        IV
# 0              departamento  0.271602
# 0           patamar_salario  0.168649
# 0       ult_avaliacao_clima  0.094439
# 0             tempo_empresa  0.088353
# 0            ID_respondente  0.032663
# 0          qtde_projetos_6m  0.031940
# 0          flag_promocao_3m  0.023954
# 0  media_horas_trabalho_12m  0.019898
# 0         qtde_projetos_24m  0.014719
# 0   media_horas_trabalho_6m  0.013801
# 0         qtde_projetos_12m  0.012572
# 0          qtde_projetos_3m  0.009395
# 0        flag_promocao_vida  0.008593
# 0   media_horas_trabalho_3m  0.004882
# 0          flag_promocao_6m  0.000115
# 0         flag_promocao_12m  0.000049

# %% [markdown]
# ### Categorização de variáveis com valores *missing* (safra de jan/23)

# %%
def freq_table_mult_col(df,var_categorica,var_resultado,quantil):
    var = f'{var_categorica}_{quantil}'
    df[var] = pd.qcut(df[var_categorica],quantil)
    cross_tab = pd.crosstab(df[var], df[var_resultado], margins=False, dropna=False)
    prop_table = cross_tab.div(cross_tab.sum(axis=1), axis=0)
    df.drop([var], axis=1, inplace=True)
    return prop_table

# %%
freq_table_mult_col(dados_turnover_jan,'ult_avaliacao_clima','turnover',3)
# Out:
# turnover                      0         1
# ult_avaliacao_clima_3
# NaN                    0.824885  0.175115
# (-0.001, 0.51]         0.782114  0.217886
# (0.51, 0.83]           0.822150  0.177850
# (0.83, 1.0]            0.871730  0.128270

# %%
freq_table_mult_col(dados_turnover_jan,'ult_avaliacao_clima','turnover',4)
# Out:
# turnover                      0         1
# ult_avaliacao_clima_4
# NaN                    0.824885  0.175115
# (-0.001, 0.39]         0.774403  0.225597
# (0.39, 0.69]           0.811050  0.188950
# (0.69, 0.88]           0.842623  0.157377
# (0.88, 1.0]            0.871429  0.128571

# %%
freq_table_mult_col(dados_turnover_jan,'ult_avaliacao_clima','turnover',5)
# Out:
# turnover                      0         1
# ult_avaliacao_clima_5
# NaN                    0.824885  0.175115
# (-0.001, 0.31]         0.772000  0.228000
# (0.31, 0.59]           0.799163  0.200837
# (0.59, 0.78]           0.814765  0.185235
# (0.78, 0.92]           0.877763  0.122237
# (0.92, 1.0]            0.861401  0.138599

# %%
freq_table_mult_col(dados_turnover_jan,'ult_avaliacao_clima','turnover',6)
# Out:
# turnover                      0         1
# ult_avaliacao_clima_6
# NaN                    0.824885  0.175115
# (-0.001, 0.245]        0.763547  0.236453
# (0.245, 0.51]          0.800322  0.199678
# (0.51, 0.69]           0.814070  0.185930
# (0.69, 0.83]           0.829688  0.170313
# (0.83, 0.93]           0.878007  0.121993
# (0.93, 1.0]            0.865672  0.134328

# %%
# Criação de variável 'ult_avaliacao_clima_cat' com cenário escolhido de categorização
dados_turnover_jan['ult_avaliacao_clima_cat'] = pd.qcut(dados_turnover_jan['ult_avaliacao_clima'], q=3)

#Criação de categoria 'Vazio' na nova variável 'ult_avaliacao_clima_cat'
dados_turnover_jan['ult_avaliacao_clima_cat'] = dados_turnover_jan['ult_avaliacao_clima_cat'].cat.add_categories("Vazio")
dados_turnover_jan['ult_avaliacao_clima_cat'] = dados_turnover_jan['ult_avaliacao_clima_cat'].fillna("Vazio")

# %% [markdown]
# ### Separação de conjuntos de treino e teste

# %%
# Aletorizando a ordem das linhas da base
dados_turnover_jan = dados_turnover_jan.sample(frac=1, random_state=12345).reset_index(drop=True)

# %%
# Separando os conjuntos de treino e teste
dados_turnover_treino, dados_turnover_teste = train_test_split(dados_turnover_jan, test_size=0.3, random_state=12345)

# %% [markdown]
# ### Modelo de regressão logística múltipla

# %% [markdown]
# #### Treino Inicial

# %%
# Definindo as variáveis preditoras e a variável resposta
features = [
'departamento',
'patamar_salario',
'ult_avaliacao_clima_cat',
'tempo_empresa',
'media_horas_trabalho_6m',
'qtde_projetos_24m',
'flag_promocao_3m',
'turnover'
]

cat_features = [
'departamento',
'patamar_salario',
'ult_avaliacao_clima_cat'
]

df_predictors = dados_turnover_treino[features]

# %%
#OneHot

onehot = encoding.OneHotEncoder(variables=cat_features)
onehot.fit(df_predictors)
df_predictors = onehot.transform(df_predictors)

# %%
predictors = df_predictors.columns.tolist()
predictors.remove('turnover')  # Removendo a variável resposta
response = 'turnover'

# %%
modelo = sm.GLM(df_predictors[response], 
                sm.add_constant(df_predictors[predictors]),
                family=sm.families.Binomial())
resultado = modelo.fit()

# %%
# print(resultado.summary())
# print(resultado.summary2())

# %%
summary_table = resultado.summary2().tables[1]

# Ajustar a precisão dos p-values
summary_table['P>|z|'] = summary_table['P>|z|'].apply(lambda x: '{:.10f}'.format(x))

# Exibir o resumo
summary_table
# Out:
#                                            Coef.  Std.Err.         z  \
# const                                  -0.739470  0.359449 -2.057232
# tempo_empresa                          -0.243407  0.038271 -6.360163
# media_horas_trabalho_6m                 0.000018  0.004293  0.004180
# qtde_projetos_24m                       0.020641  0.022881  0.902136
# flag_promocao_3m                       -0.777403  0.408678 -1.902236
# departamento_vendas                     0.493466  0.111167  4.438981
# departamento_RH/financeiro              0.176868  0.148869  1.188077
# departamento_marketing/produto         -0.222676  0.138642 -1.606131
# departamento_dados                     -1.095134  0.153037 -7.156018
# departamento_TI/suporte                -0.091994  0.124989 -0.736012
# patamar_salario_01_menor_igual_media    0.232836  0.195619  1.190249
# patamar_salario_02_acima_media         -0.972306  0.214324 -4.536611
# ult_avaliacao_clima_cat_(0.51, 0.83]   -0.173969  0.125666 -1.384376
# ult_avaliacao_clima_cat_(-0.001, 0.51]  0.112075  0.128250  0.873873
# ult_avaliacao_clima_cat_(0.83, 1.0]    -0.541568  0.136681 -3.962278
# ult_avaliacao_clima_cat_Vazio          -0.136009  0.198031 -0.686804
#
#                                                P>|z|    [0.025    0.975]
# const                                   0.0396638893 -1.443978 -0.034963
# tempo_empresa                           0.0000000002 -0.318416 -0.168398
# media_horas_trabalho_6m                 0.9966651056 -0.008396  0.008432
# qtde_projetos_24m                       0.3669843719 -0.024204  0.065487
# flag_promocao_3m                        0.0571402926 -1.578398  0.023592
# departamento_vendas                     0.0000090386  0.275584  0.711349
# departamento_RH/financeiro              0.2348030432 -0.114910  0.468646
# departamento_marketing/produto          0.1082451581 -0.494409  0.049056
# departamento_dados                      0.0000000000 -1.395081 -0.795188
# departamento_TI/suporte                 0.4617235536 -0.336968  0.152981
# patamar_salario_01_menor_igual_media    0.2339483532 -0.150571  0.616243
# patamar_salario_02_acima_media          0.0000057165 -1.392374 -0.552238
# ult_avaliacao_clima_cat_(0.51, 0.83]    0.1662433063 -0.420269  0.072332
# ult_avaliacao_clima_cat_(-0.001, 0.51]  0.3821872151 -0.139292  0.363441
# ult_avaliacao_clima_cat_(0.83, 1.0]     0.0000742380 -0.809457 -0.273678
# ult_avaliacao_clima_cat_Vazio           0.4922064965 -0.524143  0.252126

# %% [markdown]
# #### Retirando media_horas_trabalho_6m

# %%
# Definindo as variáveis preditoras e a variável resposta
features = [
'departamento',
'patamar_salario',
'ult_avaliacao_clima_cat',
'tempo_empresa',
'qtde_projetos_24m',
'flag_promocao_3m',
'turnover'
]

cat_features = [
'departamento',
'patamar_salario',
'ult_avaliacao_clima_cat'
]

df_predictors = dados_turnover_treino[features]

# %%
#OneHot

onehot = encoding.OneHotEncoder(variables=cat_features)
onehot.fit(df_predictors)
df_predictors = onehot.transform(df_predictors)

# %%
predictors = df_predictors.columns.tolist()
predictors.remove('turnover')  # Removendo a variável resposta
response = 'turnover'

# %%
modelo = sm.GLM(df_predictors[response], 
                sm.add_constant(df_predictors[predictors]),
                family=sm.families.Binomial())
resultado = modelo.fit()

# %%
summary_table = resultado.summary2().tables[1]

# Ajustar a precisão dos p-values
summary_table['P>|z|'] = summary_table['P>|z|'].apply(lambda x: '{:.10f}'.format(x))

# Exibir o resumo
summary_table
# Out:
#                                            Coef.  Std.Err.         z  \
# const                                  -0.738053  0.118944 -6.205041
# tempo_empresa                          -0.243390  0.038044 -6.397615
# qtde_projetos_24m                       0.020661  0.022411  0.921911
# flag_promocao_3m                       -0.777356  0.408523 -1.902847
# departamento_vendas                     0.493731  0.091287  5.408554
# departamento_RH/financeiro              0.177163  0.131020  1.352187
# departamento_marketing/produto         -0.222416  0.123817 -1.796322
# departamento_dados                     -1.094836  0.135293 -8.092321
# departamento_TI/suporte                -0.091696  0.102744 -0.892468
# patamar_salario_01_menor_igual_media    0.233549  0.095778  2.438445
# patamar_salario_02_acima_media         -0.971601  0.132282 -7.344927
# ult_avaliacao_clima_cat_(0.51, 0.83]   -0.173628  0.095680 -1.814668
# ult_avaliacao_clima_cat_(-0.001, 0.51]  0.112435  0.094980  1.183778
# ult_avaliacao_clima_cat_(0.83, 1.0]    -0.541194  0.103452 -5.231333
# ult_avaliacao_clima_cat_Vazio          -0.135665  0.180154 -0.753049
#
#                                                P>|z|    [0.025    0.975]
# const                                   0.0000000005 -0.971179 -0.504927
# tempo_empresa                           0.0000000002 -0.317954 -0.168825
# qtde_projetos_24m                       0.3565749783 -0.023264  0.064585
# flag_promocao_3m                        0.0570605512 -1.578046  0.023334
# departamento_vendas                     0.0000000635  0.314812  0.672651
# departamento_RH/financeiro              0.1763155986 -0.079631  0.433958
# departamento_marketing/produto          0.0724432756 -0.465093  0.020262
# departamento_dados                      0.0000000000 -1.360005 -0.829666
# departamento_TI/suporte                 0.3721419432 -0.293072  0.109679
# patamar_salario_01_menor_igual_media    0.0147505956  0.045828  0.421270
# patamar_salario_02_acima_media          0.0000000000 -1.230869 -0.712333
# ult_avaliacao_clima_cat_(0.51, 0.83]    0.0695749253 -0.361158  0.013902
# ult_avaliacao_clima_cat_(-0.001, 0.51]  0.2365009466 -0.073722  0.298592
# ult_avaliacao_clima_cat_(0.83, 1.0]     0.0000001683 -0.743957 -0.338431
# ult_avaliacao_clima_cat_Vazio           0.4514204113 -0.488761  0.217431

# %% [markdown]
# #### Retirando 0.3565749783

# %%
# Definindo as variáveis preditoras e a variável resposta
features = [
'departamento',
'patamar_salario',
'ult_avaliacao_clima_cat',
'tempo_empresa',
'flag_promocao_3m',
'turnover'
]

cat_features = [
'departamento',
'patamar_salario',
'ult_avaliacao_clima_cat'
]

df_predictors = dados_turnover_treino[features]

# %%
#OneHot

onehot = encoding.OneHotEncoder(variables=cat_features)
onehot.fit(df_predictors)
df_predictors = onehot.transform(df_predictors)

# %%
predictors = df_predictors.columns.tolist()
predictors.remove('turnover')  # Removendo a variável resposta
response = 'turnover'

# %%
modelo = sm.GLM(df_predictors[response], 
                sm.add_constant(df_predictors[predictors]),
                family=sm.families.Binomial())
resultado = modelo.fit()

# %%
modelo

# %%
summary_table = resultado.summary2().tables[1]

# Ajustar a precisão dos p-values
summary_table['P>|z|'] = summary_table['P>|z|'].apply(lambda x: '{:.10f}'.format(x))

# Exibir o resumo
summary_table
# Out:
#                                            Coef.  Std.Err.         z  \
# const                                  -0.659836  0.083043 -7.945701
# tempo_empresa                          -0.240635  0.037882 -6.352227
# flag_promocao_3m                       -0.774519  0.408531 -1.895865
# departamento_vendas                     0.507484  0.090092  5.632982
# departamento_RH/financeiro              0.191111  0.130166  1.468213
# departamento_marketing/produto         -0.205266  0.122396 -1.677063
# departamento_dados                     -1.077472  0.133915 -8.045922
# departamento_TI/suporte                -0.075693  0.101247 -0.747612
# patamar_salario_01_menor_igual_media    0.271375  0.086491  3.137607
# patamar_salario_02_acima_media         -0.931211  0.124722 -7.466314
# ult_avaliacao_clima_cat_(0.51, 0.83]   -0.156107  0.093752 -1.665111
# ult_avaliacao_clima_cat_(-0.001, 0.51]  0.134783  0.091803  1.468183
# ult_avaliacao_clima_cat_(0.83, 1.0]    -0.517789  0.100225 -5.166281
# ult_avaliacao_clima_cat_Vazio          -0.120723  0.179406 -0.672902
#
#                                                P>|z|    [0.025    0.975]
# const                                   0.0000000000 -0.822597 -0.497074
# tempo_empresa                           0.0000000002 -0.314882 -0.166387
# flag_promocao_3m                        0.0579779416 -1.575224  0.026187
# departamento_vendas                     0.0000000177  0.330908  0.684060
# departamento_RH/financeiro              0.1420463481 -0.064009  0.446230
# departamento_marketing/produto          0.0935300918 -0.445157  0.034626
# departamento_dados                      0.0000000000 -1.339941 -0.815003
# departamento_TI/suporte                 0.4546940438 -0.274133  0.122746
# patamar_salario_01_menor_igual_media    0.0017033320  0.101856  0.440895
# patamar_salario_02_acima_media          0.0000000000 -1.175661 -0.686761
# ult_avaliacao_clima_cat_(0.51, 0.83]    0.0958906966 -0.339858  0.027643
# ult_avaliacao_clima_cat_(-0.001, 0.51]  0.1420545738 -0.045147  0.314713
# ult_avaliacao_clima_cat_(0.83, 1.0]     0.0000002388 -0.714226 -0.321352
# ult_avaliacao_clima_cat_Vazio           0.5010099507 -0.472353  0.230907

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
len(df_predictors[predictors].columns)
# Out:
# 13

# %%
df_predictors[predictors].shape[1]
# Out:
# 13

# %%
 from statsmodels.stats.outliers_influence import variance_inflation_factor 
vif_data = pd.DataFrame() 
vif_data["feature"] = df_predictors[predictors].columns

vif_data["VIF"] = [variance_inflation_factor(df_predictors[predictors].values, i) 
                          for i in range(len(df_predictors[predictors].columns))] 
  
print(vif_data)
# Out:
#                                    feature       VIF
# 0                            tempo_empresa  1.025463
# 1                         flag_promocao_3m  1.021470
# 2                      departamento_vendas       inf
# 3               departamento_RH/financeiro       inf
# 4           departamento_marketing/produto       inf
# 5                       departamento_dados       inf
# 6                  departamento_TI/suporte       inf
# 7     patamar_salario_01_menor_igual_media       inf
# 8           patamar_salario_02_acima_media       inf
# 9     ult_avaliacao_clima_cat_(0.51, 0.83]       inf
# 10  ult_avaliacao_clima_cat_(-0.001, 0.51]       inf
# 11     ult_avaliacao_clima_cat_(0.83, 1.0]       inf
# 12           ult_avaliacao_clima_cat_Vazio       inf
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
